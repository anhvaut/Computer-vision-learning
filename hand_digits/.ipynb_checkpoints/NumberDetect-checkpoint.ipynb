# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from sklearn.externals import joblib
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.datasets.mldata import fetch_mldata
# Out:
# ----------------------------------------------------------------------
# ModuleNotFoundError                  Traceback (most recent call last)
# <ipython-input-2-f0d152eeb087> in <module>
# ----> 1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 import matplotlib
#       3 import matplotlib.pyplot as plt
#       4 import numpy as np
#       5 from sklearn.externals import joblib
#
# ~/anaconda3/envs/vu/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2305                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2306             with self.builtin_trap:
# -> 2307                 result = fn(*args, **kwargs)
#    2308             return result
#    2309
#
# </home/bluerain/anaconda3/envs/vu/lib/python3.6/site-packages/decorator.py:decorator-gen-108> in matplotlib(self, line)
#
# ~/anaconda3/envs/vu/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
# ...

# %% [markdown]
# ### normalize data

# %%
mnist = fetch_mldata('mnist-original', data_home='D:\HK9\TVu_RTC\CKy\HW')
X, y = mnist["data"], mnist["target"]
X = X / 255

# %% [markdown]
# ### train/test split

# %%
X0 = X[np.where(y == 0)[0]]
X1 = X[np.where(y == 1)[0]]
X = np.concatenate((X0, X1), axis=0)

y0 = np.zeros(X0.shape[0])
y1 = np.ones(X1.shape[0])
y = np.concatenate((y0, y1), axis=0)

mix = np.arange(len(y))
np.random.shuffle(mix)
X = X[mix,:]
y= y[mix]

# %%
m = 12000
m_test = X.shape[0] - m
x_train, x_test = X[:m].T, X[m:].T
y_train, y_test = y[:m].T, y[m:].T

# %%
i = 5
plt.imshow(x_train[:,i].reshape(28,28), cmap = matplotlib.cm.binary)
plt.axis("off")
plt.show()
print(y_train[i])
# Out:
# ----------------------------------------------------------------------
# NameError                            Traceback (most recent call last)
# <ipython-input-1-99855b7a5618> in <module>
#       1 i = 5
# ----> 2 plt.imshow(x_train[:,i].reshape(28,28), cmap = matplotlib.cm.binary)
#       3 plt.axis("off")
#       4 plt.show()
#       5 print(y_train[i])
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ### Define function to calculate Sigmoid

# %%
def sigmoid(z):
    s = 1 / (1 + np.exp(-z))
    return s

# %% [markdown]
# ### Define function to calculate cost Function

# %%
def compute_loss(Y, Y_hat):

    m = Y.shape[0]
    L = -(1./m) * ( np.sum( np.multiply(np.log(Y_hat),Y) ) + np.sum( np.multiply(np.log(1-Y_hat),(1-Y)) ) )

    return L

# %% [markdown]
# ### Train

# %%
learning_rate = 0.01

X = x_train
Y = y_train

n_x = X.shape[0]
m = X.shape[1]

W = np.random.randn(n_x, 1) * 0.01
b = np.zeros((1, 1))

for i in range(2000):
    Z = np.matmul(W.T, X) + b
    A = sigmoid(Z)

    cost = compute_loss(Y, A)

    dW = (1/m) * np.matmul(X, (A-Y).T)
    db = (1/m) * np.sum(A-Y, axis=1, keepdims=True)

    W = W - learning_rate * dW
    b = b - learning_rate * db

    if (i % 100 == 0):
        print("Epoch", i, "cost: ", cost)

print("Final cost:", cost)
# Out:
# Epoch 0 cost:  0.6996836926171729
# Epoch 100 cost:  0.11876929160380773
# Epoch 200 cost:  0.06979730619454397
# Epoch 300 cost:  0.051478182645738585
# Epoch 400 cost:  0.04172426359273545
# Epoch 500 cost:  0.03559843578273371
# Epoch 600 cost:  0.03136126490187197
# Epoch 700 cost:  0.02823833003530614
# Epoch 800 cost:  0.02583073360843749
# Epoch 900 cost:  0.023911308403069625
# Epoch 1000 cost:  0.022340799914104002
# Epoch 1100 cost:  0.021028888484895796
# Epoch 1200 cost:  0.019914316281731348
# Epoch 1300 cost:  0.01895400096979896
# Epoch 1400 cost:  0.018116718199839024
# Epoch 1500 cost:  0.017379257399813733
# Epoch 1600 cost:  0.0167239877904063
# Epoch 1700 cost:  0.016137264354409007
# Epoch 1800 cost:  0.015608353089008507
# Epoch 1900 cost:  0.015128687796792216
# Final cost: 0.014695528003809136

# %%
Z = np.matmul(W.T, x_test) + b
A = sigmoid(Z)

y_predict = np.where(A < 0.5, 0, 1)
labels = np.where(y_test < 0.5, 0, 1)

print(confusion_matrix(y_predict.T, labels))
# Out:
# [[1298    3]
#  [   0 1479]]

# %%
print(classification_report(y_predict.T, labels))
# Out:
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      1301
#           1       1.00      1.00      1.00      1479
#
# avg / total       1.00      1.00      1.00      2780

# %%
i = 4
plt.imshow(x_test[:,i].reshape(28, 28))
print('real: ',y_test[i],', predict: ',y_predict[:,i][0])
# Out:
# real:  1.0 , predict:  1

# %%
import cv2
im = cv2.imread('hd3.jpg')
imgray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
imgray = cv2.GaussianBlur(imgray, (5,5), 0)
plt.imshow(im)
plt.axis('off')
plt.show()

# %%
ret, im_th = cv2.threshold(imgray, 130, 255, cv2.THRESH_BINARY_INV)

kernel = np.ones((3,3),np.uint8)
im_th = cv2.erode(im_th,kernel,iterations = 1)

kernel = np.ones((3,3),np.uint8)
im_th = cv2.dilate(im_th, kernel,iterations = 3)
_,ctrs,_ = cv2.findContours(im_th.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
rects = [cv2.boundingRect(ctr) for ctr in ctrs]

# %%
for rect in rects:
    cv2.rectangle(im, (rect[0], rect[1]), (rect[0]+rect[2], rect[1] + rect[3]), (0,255,0),3)

# %%
# im_th = cv2.dilate(im_th, (3,3))
plt.imshow(im)
plt.axis('off')
plt.show()

# %%
# im = im/255

# %% [markdown]
# ### tim vung bao quanh con so

# %%
imtest = np.array([[]])
imtest2 = np.ones((28*28, 0))
for rect in rects:
    if rect[3] > 20 and rect[2] >20:
        length = int (rect[3]*1.6)
        pt1 = int(rect[1]+rect[3]//2 - length //2)
        pt2 = int(rect[0]+rect[2]//2 - length //2)
        roi = im_th[pt1:pt1+length, pt2:pt2+length]
        roi = cv2.resize(roi, (28,28), interpolation = cv2.INTER_AREA)
        roi = cv2.dilate(roi, (3,3))

        plt.imshow(roi)
        plt.axis('off')
        plt.show()
        imtest = np.array([roi]).reshape(28*28, 1)
        imtest2= np.append(imtest2, imtest, axis = 1)

# %%
Z = np.matmul(W.T, imtest2) + b
A = sigmoid(Z)
y_predict = np.where(A < 0.5, 0, 1)
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in exp

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

i = 0
for rect in rects:
    if rect[3] > 20 and rect[2] >20:
        cv2.putText(im,str(y_predict[:,i][0]),(rect[0]+rect[2], rect[1]+rect[3]), font, 2,(255,0,0),2,cv2.LINE_AA)
        i= i+1

# %%
plt.imshow(im)
plt.axis('off')
plt.show()
